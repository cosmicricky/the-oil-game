# %%
import sys
from pathlib import Path
sys.path.append(str(Path("../src").resolve()))

# %%
from simulation import Simulation

sim = Simulation(
    delay=0,
    pricing="hybrid"
)
sim.run(duration=26) # 6 months
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 7
#       1 from simulation import Simulation
#       3 sim = Simulation(
#       4     delay=0,
#       5     pricing="hybrid"
#       6 )
# ----> 7 sim.run(duration=26) # 6 months
#
# File ~\Desktop\Simulations\the-oil-game\src\simulation.py:77, in Simulation.run(self, duration)
#      68 for t in range(1, duration + 1):
#      69     # Example demand shock:
#      70     # demand = 5.0 if t < 10 else 10.0
#      72     order = naive_policy(
#      73         self.depot.inventory,
#      74         self.target_inventory
#      75     )
# ---> 77     result = self.depot.step(demand, order)
#      78     price = self.compute_price(t)
#      80     self.history.append({
#      81         "timestep": t,
#      82         "demand": demand,
#    (...)     86         "price": price
#      87     })
#
# File ~\Desktop\Simulations\the-oil-game\src\facility.py:29, in Facility.step(self, demand, order)
#      25 """
#      26 Advance the simulation by one time step.
#      27 """
#      28 # 1. Receive shipments from pipeline
# ---> 29 if self.delay == 0:
#      30     # NOTE: orders arrive immediately (no transport delay)
#      31     incoming = order
#      32 else:
#      33     # NOTE: FIFO fixed transport delay
#
# AttributeError: 'Facility' object has no attribute 'delay'

# %%
# %matplotlib widget
from visualizer import Visualizer

viz = Visualizer(sim.history)
viz.show()
