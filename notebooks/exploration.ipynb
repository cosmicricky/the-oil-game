# %%
import sys
from pathlib import Path
sys.path.append(str(Path("../src").resolve()))

# %%
from simulation import Simulation

sim = Simulation()
sim.run(duration=20)
sim.history[:20]
# Out:
# [{'timestep': 0, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 1, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 2, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 3, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 4, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 5, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 6, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 7, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 8, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 9, 'demand': 4, 'inventory': 20, 'backlog': 0},
#  {'timestep': 10, 'demand': 8, 'inventory': 20, 'backlog': 0},
#  {'timestep': 11, 'demand': 8, 'inventory': 20, 'backlog': 0},
#  {'timestep': 12, 'demand': 8, 'inventory': 20, 'backlog': 0},
#  {'timestep': 13, 'demand': 8, 'inventory': 20, 'backlog': 0},
#  {'timestep': 14, 'demand': 8, 'inventory': 20, 'backlog': 0},
# ...
